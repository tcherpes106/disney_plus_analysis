# %% [markdown]
# # SQL Analysis

# %% [markdown]
# ## Questions to answer

# %% [markdown]
# Main Question :
#
# 1. How could Disney+ add to their catalog to see an uptick in subscriptions to the site?
#
# Related Questions:
#
# 2. What specific areas in terms of genre, year, or rating should be added?
# 3. Which projects should Disney try to emulate from their existing catalog to see future success?

# %% [markdown]
# Load SQL extension

# %%
# %load_ext sql

# %% [markdown]
# Connect to database

# %%
# %sql mysql://USERNAME:PASSWORD@HOST/DATABASE

# %% [markdown]
# ## Exploratory Queries

# %% [markdown]
# ### Exploratory Query 1

# %% [markdown]
# This query's purpose is to see which years are represented the most on the Disney+ site.

# %%
# %%sql
# SELECT
#     year,
#     COUNT(*) AS total_movies
# FROM disney_plus
# GROUP BY year
# ORDER BY COUNT(*) DESC;
# Out:
#  * mysql://admin:***@lmu-dev-01.czdondpz1m2v.us-east-2.rds.amazonaws.com/sql_project
# 80 rows affected.
# [('2019', 49),
#  ('2017', 36),
#  ('2018', 30),
#  ('2016', 30),
#  ('2005', 27),
#  ('2003', 27),
#  ('2006', 27),
#  ('2011', 25),
#  ('2012', 25),
#  ('2002', 23),
#  ('2004', 23),
#  ('2000', 23),
#  ('2014', 21),
#  ('2015', 21),
#  ('1999', 21),
#  ('1998', 21),
#  ('2010', 20),
#  ('2009', 19),
#  ('2008', 19),
#  ('2001', 19),
#  ('2007', 18),
#  ('2013', 17),
#  ('2020', 17),
#  ('1996', 12),
#  ('1993', 12),
#  ('1994', 11),
#  ('1995', 11),
#  ('1997', 11),
#  ('1992', 8),
#  ('1977', 8),
#  ('1986', 6),
#  ('1989', 6),
#  ('1979', 5),
#  ('1981', 5),
#  ('1991', 5),
#  ('1985', 5),
#  ('1961', 5),
#  ('1959', 5),
#  ('1987', 5),
#  ('1975', 4),
#  ('1988', 4),
#  ('1955', 4),
#  ('1971', 4),
#  ('1980', 4),
#  ('1990', 4),
#  ('1976', 3),
#  ('1950', 3),
#  ('1953', 3),
#  ('1940', 3),
#  ('1957', 3),
#  ('1965', 3),
#  ('1952', 3),
#  ('1972', 3),
#  ('1969', 3),
#  ('1974', 3),
#  ('1962', 3),
#  ('1947', 2),
#  ('1951', 2),
#  ('1967', 2),
#  ('1954', 2),
#  ('1964', 2),
#  ('1958', 2),
#  ('1956', 2),
#  ('1963', 2),
#  ('1978', 2),
#  ('1960', 2),
#  ('1941', 2),
#  ('1983', 1),
#  ('1942', 1),
#  ('1970', 1),
#  ('1968', 1),
#  ('1984', 1),
#  ('1948', 1),
#  ('1944', 1),
#  ('1966', 1),
#  ('1982', 1),
#  ('1943', 1),
#  ('1937', 1),
#  ('1973', 1),
#  ('1949', 1)]

# %% [markdown]
# This query shows how the amount of content per year on the Disney+ site folllows an almost linear trend, with each year adding more content.

# %% [markdown]
# ### Exploratory Query 2 and 3

# %% [markdown]
# These queries' purpose is to show the average year from the IMDb top 250 movie list and the Rotten Tomatoes top 100 mobie list.

# %%
# %%sql
# SELECT
#     ROUND(AVG(year)) AS average_year_imdb
# FROM imdb;
# Out:
#  * mysql://admin:***@lmu-dev-01.czdondpz1m2v.us-east-2.rds.amazonaws.com/sql_project
# 1 rows affected.
# [(1986.0,)]

# %%
# %%sql
# SELECT
#     ROUND(AVG(year)) AS average_year_rotten_tomatoes
# FROM rotten_tomatoes;
# Out:
#  * mysql://admin:***@lmu-dev-01.czdondpz1m2v.us-east-2.rds.amazonaws.com/sql_project
# 1 rows affected.
# [(1989.0,)]

# %% [markdown]
# These queries show how the average year for highly rated/popular films is around the 1980s. This is interesting as we just found how Disney+'s catalog is much more heavily weighted on new/very recent content.

# %% [markdown]
# ### Exploratory Query 4 and 5

# %% [markdown]
# These queries' purpose is to show which genres IMDb and RottenTomatoes have movies listed in their top films.

# %%
# %%sql
# SELECT
#     genre,
#     COUNT(*) AS genre_count_imdb
# FROM imdb
# GROUP BY genre
# ORDER BY COUNT(*) DESC;
# Out:
#  * mysql://admin:***@lmu-dev-01.czdondpz1m2v.us-east-2.rds.amazonaws.com/sql_project
# 16 rows affected.
# [('Drama', 79),
#  ('War', 22),
#  ('Crime', 20),
#  ('Action', 19),
#  ('Comedy', 18),
#  ('Sci-fi', 13),
#  ('Thriller', 12),
#  ('Family', 12),
#  ('Romance', 11),
#  ('Fantasy', 9),
#  ('Western', 8),
#  ('Mystery', 8),
#  ('Musical', 7),
#  ('Adventure', 5),
#  ('Horror', 4),
#  ('Noir', 3)]

# %%
# %%sql
# SELECT
#     genre,
#     COUNT(*) AS genre_count_rotten_tomatoes
# FROM rotten_tomatoes
# GROUP BY genre
# ORDER BY COUNT(*) DESC;
# Out:
#  * mysql://admin:***@lmu-dev-01.czdondpz1m2v.us-east-2.rds.amazonaws.com/sql_project
# 14 rows affected.
# [('Drama', 22),
#  ('Action', 11),
#  ('Romance', 9),
#  ('Musical', 8),
#  ('Family', 8),
#  ('Horror', 7),
#  ('Sci-fi', 7),
#  ('Noir', 6),
#  ('Crime', 5),
#  ('War', 5),
#  ('Comedy', 4),
#  ('Thriller', 3),
#  ('Adventure', 3),
#  ('Mystery', 2)]

# %% [markdown]
# These queries show how for both IMDb and RottenTomatoes, many of the top movies fall into the drama genre.

# %% [markdown]
# ### Exploratory Query 6 and 7

# %% [markdown]
# These queries' purpose is to show which ratings IMDb and RottenTomatoes have movies listed in their top films.

# %%
# %%sql
# SELECT
#     rating,
#     COUNT(*) AS rating_count_imdb
# FROM imdb
# GROUP BY rating
# ORDER BY COUNT(*) DESC;
# Out:
#  * mysql://admin:***@lmu-dev-01.czdondpz1m2v.us-east-2.rds.amazonaws.com/sql_project
# 5 rows affected.
# [('R', 101), ('N/A', 52), ('PG', 41), ('PG-13', 36), ('G', 20)]

# %%
# %%sql
# SELECT
#     rating,
#     COUNT(*) AS rating_count_rotten_tomatoes
# FROM rotten_tomatoes
# GROUP BY rating
# ORDER BY COUNT(*) DESC;
# Out:
#  * mysql://admin:***@lmu-dev-01.czdondpz1m2v.us-east-2.rds.amazonaws.com/sql_project
# 5 rows affected.
# [('R', 37), ('N/A', 22), ('PG', 18), ('PG-13', 18), ('G', 5)]

# %% [markdown]
# These queries show how for both IMDb and RottenTomatoes, the MPAA rating with the most top movies is 'R'.

# %% [markdown]
# ## Question Queries

# %% [markdown]
# ### Main Question Query

# %% [markdown]
# How could Disney+ add to their catalog to see an uptick in subscriptions to the site?
#
# This query's purpose is to see which rating of movie Disney+ should add to its catalog by ranking the combined results of the IMDb top 250 and RottenTomatoes top 100 by rating.
#
# This query will allow Disney+ to see which rating of movie is most popular/is viewed as the best films. By adding more films that are in line with the highest ranked ratings, the site can hopefully pull in more customers who may be intrguied with the new content.
#
# SQL Features Used:
#     GROUP BY,
#     CTE,
#     Subquery,
#     Window Function (RANK)

# %%
# %%sql
# WITH rating_totals AS (
#     SELECT
#         COUNT(*) AS total_movies,
#         rating
#     FROM
#     (
#         SELECT
#             'rotten_tomatoes' AS source,
#             rating
#         FROM rotten_tomatoes rt
#         UNION ALL
#         SELECT
#             'imdb' AS source,
#             rating
#         FROM imdb i
#     ) joined_imdb_rotten_tomatoes
#     GROUP BY rating
#     ORDER BY COUNT(*) DESC
# )
# SELECT
#     RANK() OVER (ORDER BY total_movies DESC) AS rating_rank,
#     rating,
#     total_movies
# FROM rating_totals;
# Out:
#  * mysql://admin:***@lmu-dev-01.czdondpz1m2v.us-east-2.rds.amazonaws.com/sql_project
# 5 rows affected.
# [(1, 'R', 138), (2, 'N/A', 74), (3, 'PG', 59), (4, 'PG-13', 54), (5, 'G', 25)]

# %% [markdown]
# Based on the results of this query, Disney+ should add rated 'R' content to their catalog, as it is the highest ranked rating by a wide margin. The Disney+ catalog currently has zero 'R' rated films - Since crime, war, and drama movies, which we found to be the most popular genres, are usually rated 'R', Disney+ should consider adding a new tab to their site for more adult content. By essentially alienating the most popular movie rating, and subsequently genres attached to it, Disney+ has placed a cap on their maximum consumers. To bolster subscriptions, the site should consider branching out and pulling in consumers who are more interested in more adult movies rather than family comedys and musicals.

# %% [markdown]
# ### Related Question Queries #1

# %% [markdown]
# Which projects should Disney try to emulate from their existing catalog to see future success?
#
# If Disney+ is unwilling to add 'R' rated films to their site, they should instead try to emulate the success found from their previous films.
#
# This query will allow Disney+ to see which of their movies are found in the IMDb top 250 and RottenTomatoes top 100 movies list - If a Disney film has found its way onto both lists, it's safe to say that it's a good movie. Disney should look into these results to see what made them instant hits in hopes to emulate their success.
#
# SQL Features Used:
#     CASE,
#     VIEW,
#     JOIN,
#     Subquery

# %%
# %%sql
# CREATE VIEW disney_movies_in_other_sites AS
# 	SELECT
# 	  dp.title,
# 	  CASE
# 	    WHEN EXISTS (SELECT *
# 	                 FROM imdb i
# 	                 WHERE i.title = dp.title)
# 	    THEN 'Yes'
# 	  END AS in_imdb,
# 	  CASE
# 	    WHEN EXISTS (SELECT *
# 	                 FROM rotten_tomatoes rt
# 	                 WHERE rt.title = dp.title)
# 	    THEN 'Yes'
# 	  END AS in_rt,
# 	  CASE
# 	    WHEN EXISTS (SELECT *
# 	                 FROM rotten_tomatoes rt
# 	                 JOIN imdb i
# 	                 	ON rt.title = i.title
# 	                 WHERE rt.title = dp.title)
# 	    THEN 'Yes'
# 	  END AS in_both
# 	FROM
# 	  disney_plus dp
# 	ORDER BY
# 		in_both DESC,
# 		in_imdb DESC,
# 		in_rt DESC;
# Out:
#  * mysql://admin:***@lmu-dev-01.czdondpz1m2v.us-east-2.rds.amazonaws.com/sql_project
# 0 rows affected.
# []

# %%
# %%sql
# SELECT *
# FROM disney_movies_in_other_sites;
# Out:
#  * mysql://admin:***@lmu-dev-01.czdondpz1m2v.us-east-2.rds.amazonaws.com/sql_project
# 770 rows affected.
# [('Coco', 'Yes', 'Yes', 'Yes'),
#  ('Avengers: Endgame', 'Yes', 'Yes', 'Yes'),
#  ('The Kid', 'Yes', 'Yes', 'Yes'),
#  ('Inside Out', 'Yes', 'Yes', 'Yes'),
#  ('The Sound of Music', 'Yes', None, None),
#  ('WALL-E', 'Yes', None, None),
#  ('Toy Story', 'Yes', None, None),
#  ('Aladdin', 'Yes', None, None),
#  ('Pirates of the Caribbean: The Curse of the Black Pearl', 'Yes', None, None),
#  ('Beauty and the Beast', 'Yes', None, None),
#  ('The Lion King', 'Yes', None, None),
#  ('Ratatouille', 'Yes', None, None),
#  ('Monsters, Inc.', 'Yes', None, None),
#  ('Aladdin', 'Yes', None, None),
#  ('The Incredibles', 'Yes', None, None),
#  ('The Lion King', 'Yes', None, None),
#  ('Finding Nemo', 'Yes', None, None),
#  ('Toy Story 3', 'Yes', None, None),
#  ('Toy Story 4', None, 'Yes', None),
#  ('Snow White and the Seven Dwarfs', None, 'Yes', None),
#  ('Zootopia', None, 'Yes', None),
#  ('Black Panther', None, 'Yes', None),
#  ('TRON: Legacy', None, None, None),
#  ('Aladdin and the King of Thieves', None, None, None),
#  ('TRON: Uprising', None, None, None),
#  ('Lady and the Tramp II: Scamp’s Adventure', None, None, None),
#  ('Lamp Life', None, None, None),
#  ('Muppet Treasure Island', None, None, None),
#  ('Brain Games', None, None, None),
#  ('Muppets Most Wanted', None, None, None),
#  ('Drain Alcatraz', None, None, None),
#  ('Phineas and Ferb', None, None, None),
#  ('The Brave Little Toaster Goes to Mars', None, None, None),
#  ('Breaking2', None, None, None),
#  ('Up, Up and Away', None, None, None),
#  ('Halloweentown', None, None, None),
#  ('101 Dalmatians', None, None, None),
#  ('Inspector Gadget', None, None, None),
#  ('Home on the Range', None, None, None),
#  ('Jungle 2 Jungle', None, None, None),
#  ('The Santa Clause 2', None, None, None),
#  ('Lady and the Tramp', None, None, None),
#  ('Shipwrecked', None, None, None),
#  ('Star Wars: Episode VI – Return of the Jedi', None, None, None),
#  ('The Avengers', None, None, None),
#  ('Miles from Tomorrowland', None, None, None),
#  ('The Ugly Dachshund', None, None, None),
#  ('Tangled: Before Ever After', None, None, None),
#  ('Muppet Babies', None, None, None),
#  ('Miracle Landing on the Hudson', None, None, None),
#  ('Crash & Bernstein', None, None, None),
#  ('Ultimate Spider-Man', None, None, None),
#  ('Big Hero 6: The Series', None, None, None),
#  ('Spider-Man and His Amazing Friends', None, None, None),
#  ('Pixar In Real Life', None, None, None),
#  ('Dr. K’s Exotic Animal ER', None, None, None),
#  ('Hercules: The Animated Series', None, None, None),
#  ('Iron Man', None, None, None),
#  ('Davy Crockett, King of the Wild Frontier', None, None, None),
#  ('Mighty Ducks', None, None, None),
#  ('Short Circuit', None, None, None),
#  ('Johnny Tsunami', None, None, None),
#  ('The Shaggy D.A.', None, None, None),
#  ('Quints', None, None, None),
#  ('Pocahontas', None, None, None),
#  ('Mickey and the Roadster Racers', None, None, None),
#  ('That’s So Raven', None, None, None),
#  ('Toy Story 2', None, None, None),
#  ('The Tigger Movie', None, None, None),
#  ('Star Wars: Episode VII – The Force Awakens', None, None, None),
#  ('Mickey Mouse Clubhouse', None, None, None),
#  ('Frenemies', None, None, None),
#  ('Now You See It…', None, None, None),
#  ('Buried Secrets of the Bible with Albert Lin', None, None, None),
#  ('Jessie', None, None, None),
#  ('Millions', None, None, None),
#  ('Camp Nowhere', None, None, None),
#  ('Honey, We Shrunk Ourselves', None, None, None),
#  ('The Secret of the Magic Gourd', None, None, None),
#  ('Tree Climbing Lions', None, None, None),
#  ('So Weird', None, None, None),
#  ('Disney Family Sundays', None, None, None),
#  ('Togo', None, None, None),
#  ('Bizarre Dinosaurs', None, None, None),
#  ('That Darn Cat!', None, None, None),
#  ('Kickin’ It', None, None, None),
#  ('The Castaway Cowboy', None, None, None),
#  ('Life Below Zero', None, None, None),
#  ('Pinocchio', None, None, None),
#  ('Emil and the Detectives', None, None, None),
#  ('Boy Meets World', None, None, None),
#  ('A Bug’s Life', None, None, None),
#  ('The Book of Pooh', None, None, None),
#  ('Deep Blue', None, None, None),
#  ('The Cat from Outer Space', None, None, None),
#  ('Flight of the Navigator', None, None, None),
#  ('Fury Files', None, None, None),
#  ('Stargirl', None, None, None),
#  ('The Biscuit Eater', None, None, None),
#  ('Pirates of the Caribbean: On Stranger Tides', None, None, None),
#  ('Hounded', None, None, None),
#  ('G-Force', None, None, None),
#  ('Lilo & Stitch', None, None, None),
#  ('Fun and Fancy Free', None, None, None),
#  ('Just Like Me', None, None, None),
#  ('Finding Dory', None, None, None),
#  ('Gargoyles', None, None, None),
#  ('Ducktales the Movie: Treasure of the Lost Lamp', None, None, None),
#  ('Tru Confessions', None, None, None),
#  ('Wizards Of Waverly Place', None, None, None),
#  ('Invincible', None, None, None),
#  ('Mickey’s Twice Upon a Christmas', None, None, None),
#  ('Good Luck Charlie, It’s Christmas!', None, None, None),
#  ('Dolphin Reef', None, None, None),
#  ('The African Lion', None, None, None),
#  ('Sea of Hope: America’s Underwater Treasures', None, None, None),
#  ('Descendants 2', None, None, None),
#  ('Goof Troop', None, None, None),
#  ('The Scream Team', None, None, None),
#  ('Sister Act', None, None, None),
#  ('Soy Luna', None, None, None),
#  ('Marvel Rising', None, None, None),
#  ('Shop Class', None, None, None),
#  ('The Santa Clause 3: The Escape Clause', None, None, None),
#  ('Newsies', None, None, None),
#  ('The Game Plan', None, None, None),
#  ('The Lion Guard', None, None, None),
#  ('Sleeping Beauty', None, None, None),
#  ('Buffalo Dreams', None, None, None),
#  ('Invisible Sister', None, None, None),
#  ('Inspector Gadget 2', None, None, None),
#  ('Bedtime Stories', None, None, None),
#  ('Full-Court Miracle', None, None, None),
#  ('Penguins', None, None, None),
#  ('The Mandalorian', None, None, None),
#  ('Cinderella', None, None, None),
#  ('Nature’s Half Acre', None, None, None),
#  ('Handy Manny', None, None, None),
#  ('Frankenweenie', None, None, None),
#  ('The Other Me', None, None, None),
#  ('Ready to Run', None, None, None),
#  ('The Fox and the Hound', None, None, None),
#  ('Shake It Up', None, None, None),
#  ('Wicked Tuna', None, None, None),
#  ('Descendants 3', None, None, None),
#  ('Under The Sea: A Descendants Short Story', None, None, None),
#  ('Sheriff Callie’s Wild West', None, None, None),
#  ('Once Upon a Mattress', None, None, None),
#  ('Wendy Wu: Homecoming Warrior', None, None, None),
#  ('Flubber', None, None, None),
#  ('How to Build a Better Boy', None, None, None),
#  ('Tinker Bell and the Lost Treasure', None, None, None),
#  ('The Chronicles of Narnia: The Lion, the Witch and the Wardrobe', None, None, None),
#  ('The BFG', None, None, None),
#  ('Hocus Pocus', None, None, None),
#  ('Star Wars: The Clone Wars', None, None, None),
#  ('The Proud Family Movie', None, None, None),
#  ('Silver Surfer', None, None, None),
#  ('Wizards of Waverly Place: The Movie', None, None, None),
#  ('Diana: In Her Own Words', None, None, None),
#  ('Drain The Sunken Pirate City', None, None, None),
#  ('Davy Crockett and the River Pirates', None, None, None),
#  ('Noelle', None, None, None),
#  ('Dadnapped', None, None, None),
#  ('The Suite Life of Zack & Cody', None, None, None),
#  ('Pooh’s Grand Adventure: The Search for Christopher Robin', None, None, None),
#  ('Dumbo', None, None, None),
#  ('Den Brother', None, None, None),
#  ('TRON', None, None, None),
#  ('Alice in Wonderland', None, None, None),
#  ('The Princess and the Frog', None, None, None),
#  ('Cheetah', None, None, None),
#  ('Garfield: A Tail of Two Kitties', None, None, None),
#  ('Zenon: The Zequel', None, None, None),
#  ('The Little Mermaid Live', None, None, None),
#  ('The Young Black Stallion', None, None, None),
#  ('How Dogs Got Their Shapes', None, None, None),
#  ('Mom’s Got a Date With a Vampire', None, None, None),
#  ('Car SOS', None, None, None),
#  ('Jump In!', None, None, None),
#  ('Dog Whisperer with Cesar Millan', None, None, None),
#  ('The Emperor’s New School', None, None, None),
#  ('The Sandlot: Heading Home', None, None, None),
#  ('Coop & Cami Ask the World', None, None, None),
#  ('The Lost Tomb of Alexander the Great', None, None, None),
#  ('Queen of Katwe', None, None, None),
#  ('The Santa Clause', None, None, None),
#  ('Even Stevens', None, None, None),
#  ('Sonny with a Chance', None, None, None),
#  ('Chimpanzee', None, None, None),
#  ('Hannah Montana', None, None, None),
#  ('World’s Greatest Dogs', None, None, None),
#  ('Hannah Montana: The Movie', None, None, None),
#  ('Life-Size 2', None, None, None),
#  ('Bizaardvark', None, None, None),
#  ('Birth of Europe', None, None, None),
#  ('Secrets of the Zoo', None, None, None),
#  ('The Suite Life on Deck', None, None, None),
#  ('Hatching Pete', None, None, None),
#  ('Big Hero 6', None, None, None),
#  ('White Wilderness', None, None, None),
#  ('Diary of a Wimpy Kid', None, None, None),
#  ('Tinker Bell', None, None, None),
#  ('Smart House', None, None, None),
#  ('Wild Russia', None, None, None),
#  ('Frozen 2', None, None, None),
#  ('Star Wars Rebels', None, None, None),
#  ('College Road Trip', None, None, None),
#  ('Blank Check', None, None, None),
#  ('George of the Jungle', None, None, None),
#  ('Justin Morgan Had a Horse', None, None, None),
#  ('Herbie: Fully Loaded', None, None, None),
#  ('Starstruck', None, None, None),
#  ('Lilo & Stitch: The Series', None, None, None),
#  ('Escape to Witch Mountain', None, None, None),
#  ('Origins: The Journey of Humankind', None, None, None),
#  ('Zombies', None, None, None),
#  ('Life Is Ruff', None, None, None),
#  ('Snow Dogs', None, None, None),
#  ('Pooh’s Heffalump Movie', None, None, None),
#  ('Flicka', None, None, None),
#  ('Oliver & Company', None, None, None),
#  ('Blackbeard’s Ghost', None, None, None),
#  ('Running Wild with Bear Grylls', None, None, None),
#  ('The Color of Friendship', None, None, None),
#  ('The Crimson Wing: Mystery of the Flamingos', None, None, None),
#  ('The Muppet Movie', None, None, None),
#  ('Iron Man', None, None, None),
#  ('Drain The Titanic', None, None, None),
#  ('Little Einsteins', None, None, None),
#  ('Iron Man: Armored Adventures', None, None, None),
#  ('DuckTales', None, None, None),
#  ('Treasure Island', None, None, None),
#  ('Iron Man & Hulk: Heroes United', None, None, None),
#  ('Forky Asks A Question', None, None, None),
#  ('Frozen', None, None, None),
#  ('Turner & Hooch', None, None, None),
#  ('Homeward Bound II: Lost in San Francisco', None, None, None),
#  ('The Jungle Book', None, None, None),
#  ('One Strange Rock', None, None, None),
#  ('The Emperor’s New Groove', None, None, None),
#  ('John Carter', None, None, None),
#  ('Cars 2', None, None, None),
#  ('Prop Culture', None, None, None),
#  ('The Rescuers Down Under', None, None, None),
#  ('Cinderella III: A Twist in Time', None, None, None),
#  ('Motocrossed', None, None, None),
#  ('Don’t Look Under the Bed', None, None, None),
#  ('Return to Halloweentown', None, None, None),
#  ('Pirates of the Caribbean: At World’s End', None, None, None),
#  ('Zenon: Z3', None, None, None),
#  ('Kim Possible', None, None, None),
#  ('Willow', None, None, None),
#  ('Empire of Dreams: The Story of the Star Wars Trilogy', None, None, None),
#  ('Bluey', None, None, None),
#  ('Frank and Ollie', None, None, None),
#  ('Atlantis: The Lost Empire', None, None, None),
#  ('The Princess Diaries', None, None, None),
#  ('Garfield: The Movie', None, None, None),
#  ('Three Men and a Baby', None, None, None),
#  ('Bambi', None, None, None),
#  ('A Kid in King Arthur’s Court', None, None, None),
#  ('The Country Bears', None, None, None),
#  ('Tiger Cruise', None, None, None),
#  ('My Favorite Martian', None, None, None),
#  ('Around The World In 89 Days', None, None, None),
#  ('Almost Angels', None, None, None),
#  ('Phil of the Future', None, None, None),
#  ('Timon & Pumbaa', None, None, None),
#  ('Lost Treasures of the Maya', None, None, None),
#  ('Alley Cats Strike', None, None, None),
#  ('Dr. T, Lone Star Vet', None, None, None),
#  ('Captain America: The Winter Soldier', None, None, None),
#  ('Secrets of the King Cobra', None, None, None),
#  ('The Lodge', None, None, None),
#  ('Born in China', None, None, None),
#  ('Pick of the Litter', None, None, None),
#  ('Cow Belles', None, None, None),
#  ('Journey to Shark Eden', None, None, None),
#  ('The Strongest Man in the World', None, None, None),
#  ('Survive the Tribe', None, None, None),
#  ('Smart Guy', None, None, None),
#  ('The Aristocats', None, None, None),
#  ('JONAS', None, None, None),
#  ('Old Yeller', None, None, None),
#  ('The Black Hole', None, None, None),
#  ('Who Framed Roger Rabbit', None, None, None),
#  ('Fast Layne', None, None, None),
#  ('Pirates of the Caribbean: Dead Man’s Chest', None, None, None),
#  ('Drain the Oceans', None, None, None),
#  ('The Last Song', None, None, None),
#  ('Cadet Kelly', None, None, None),
#  ('Miracle on 34th Street', None, None, None),
#  ('Halloweentown II: Kalabar’s Revenge', None, None, None),
#  ('Three Days', None, None, None),
#  ('The Finest Hours', None, None, None),
#  ('Lego Star Wars: All-Stars', None, None, None),
#  ('Wolverine and the X-Men', None, None, None),
#  ('Iron Man 3', None, None, None),
#  ('Chip ‘n’ Dale: Rescue Rangers', None, None, None),
#  ('The Luck of the Irish', None, None, None),
#  ('Mickey’s Once Upon a Christmas', None, None, None),
#  ('Recess: School’s Out', None, None, None),
#  ('Bad Hair Day', None, None, None),
#  ('Holes', None, None, None),
#  ('The Little Mermaid: Ariel’s Beginning', None, None, None),
#  ('Continent 7: Antarctica', None, None, None),
#  ('Eddie’s Million Dollar Cook-Off', None, None, None),
#  ('Gordon Ramsay: Uncharted', None, None, None),
#  ('Star Wars: Episode II – Attack of the Clones', None, None, None),
#  ('Richie Rich’s Christmas Wish', None, None, None),
#  ('The Incredible Dr. Pol', None, None, None),
#  ('The Shaggy Dog', None, None, None),
#  ('Avalon High', None, None, None),
#  ('Santa Paws 2: The Santa Pups', None, None, None),
#  ('Star Wars Resistance', None, None, None),
#  ('Drain The Ocean: WWII', None, None, None),
#  ('Alice Through The Looking Glass', None, None, None),
#  ('The Mistle-Tones', None, None, None),
#  ('The Computer Wore Tennis Shoes', None, None, None),
#  ('The Parent Trap', None, None, None),
#  ('Hacksaw', None, None, None),
#  ('Homeward Bound: The Incredible Journey', None, None, None),
#  ('Stitch! The Movie', None, None, None),
#  ('TaleSpin', None, None, None),
#  ('Kim Possible', None, None, None),
#  ('Star Wars: Episode IV – A New Hope', None, None, None),
#  ('Babes in Toyland', None, None, None),
#  ('Valiant', None, None, None),
#  ('The Adventures of Bullwhip Griffin', None, None, None),
#  ('The Incredible Hulk', None, None, None),
#  ('Year Million', None, None, None),
#  ('Dr. Dolittle', None, None, None),
#  ('The Great Mouse Detective', None, None, None),
#  ('Can of Worms', None, None, None),
#  ('Iron Will', None, None, None),
#  ('Because of Winn-Dixie', None, None, None),
#  ('Man in Space', None, None, None),
#  ('Star Wars: Episode V – The Empire Strikes Back', None, None, None),
#  ('Kingdom of the Blue Whale', None, None, None),
#  ('The World According to Jeff Goldblum', None, None, None),
#  ('Tinker Bell and the Great Fairy Rescue', None, None, None),
#  ('Love & Vets', None, None, None),
#  ('Girl Meets World', None, None, None),
#  ('Brother Bear 2', None, None, None),
#  ('The Story of Robin Hood and His Merrie Men', None, None, None),
#  ('Snowball Express', None, None, None),
#  ('Elephant', None, None, None),
#  ('Monkey Kingdom', None, None, None),
#  ('Dr. Oakley, Yukon Vet', None, None, None),
#  ('Beauty and the Beast: The Enchanted Christmas', None, None, None),
#  ('Lilo & Stitch 2: Stitch Has a Glitch', None, None, None),
#  ('First Class Chefs: Family Style', None, None, None),
#  ('The Proud Family', None, None, None),
#  ('Hulk and the Agents of S.M.A.S.H.', None, None, None),
#  ('The Imagineering Story', None, None, None),
#  ('Saving Mr. Banks', None, None, None),
#  ('Miracle', None, None, None),
#  ('Adventures of the Gummi Bears', None, None, None),
#  ('My Dog, the Thief', None, None, None),
#  ('Lemonade Mouth', None, None, None),
#  ('The Christmas Star', None, None, None),
#  ('The Vanishing Prairie', None, None, None),
#  ('An Extremely Goofy Movie', None, None, None),
#  ('You Lucky Dog', None, None, None),
#  ('The Suite Life Movie', None, None, None),
#  ('Greyfriars Bobby', None, None, None),
#  ('‘Twas the Night', None, None, None),
#  ('The Jennie Project', None, None, None),
#  ('Free Solo', None, None, None),
#  ('Belle’s Magical World', None, None, None),
#  ('The Princess Bride', None, None, None),
#  ('National Treasure', None, None, None),
#  ('Marvel’s Hero Project', None, None, None),
#  ('The Apple Dumpling Gang Rides Again', None, None, None),
#  ('Cheaper By The Dozen', None, None, None),
#  ('Genius', None, None, None),
#  ('Brother Bear', None, None, None),
#  ('Kazaam', None, None, None),
#  ('Camp Rock', None, None, None),
#  ('A Wrinkle in Time', None, None, None),
#  ('Mars: Inside SpaceX', None, None, None),
#  ('Skyrunners', None, None, None),
#  ('Darby O’Gill and the Little People', None, None, None),
#  ('Brave', None, None, None),
#  ('Minutemen', None, None, None),
#  ('The New Adventures of Winnie the Pooh', None, None, None),
#  ('Kirby Bucket', None, None, None),
#  ('Paris to Pittsburgh', None, None, None),
#  ('Jane Goodall: The Hope', None, None, None),
#  ('Marvel Rising: Secret Warriors', None, None, None),
#  ('Monsters University', None, None, None),
#  ('Right on Track', None, None, None),
#  ('I’ll Be Home for Christmas', None, None, None),
#  ('10 Things I Hate About You', None, None, None),
#  ('Atlantis Rising', None, None, None),
#  ('Piglet’s Big Movie', None, None, None),
#  ('Candleshoe', None, None, None),
#  ('The Little Mermaid', None, None, None),
#  ('Winnie the Pooh: Springtime With Roo', None, None, None),
#  ('Hercules', None, None, None),
#  ('Herbie Rides Again', None, None, None),
#  ('Wings of Life', None, None, None),
#  ('One Day At Disney', None, None, None),
#  ('Earth Live', None, None, None),
#  ('Pixel Perfect', None, None, None),
#  ('SparkShorts', None, None, None),
#  ('Thor: The Dark World', None, None, None),
#  ('The Love Bug', None, None, None),
#  ('Mulan II', None, None, None),
#  ('The Wild', None, None, None),
#  ('The Chronicles of Narnia: Prince Caspian', None, None, None),
#  ('Melody Time', None, None, None),
#  ('Annie', None, None, None),
#  ('The Hunchback of Notre Dame', None, None, None),
#  ('America’s National Parks', None, None, None),
#  ('Disney’s Fairy Tale Weddings', None, None, None),
#  ('The Reluctant Dragon', None, None, None),
#  ('Onward', None, None, None),
#  ('The Cheetah Girls', None, None, None),
#  ('Amphibia', None, None, None),
#  ('Lost Treasures of Egypt', None, None, None),
#  ('Drain The Bermuda Triangle', None, None, None),
#  ('Expedition Mars: Spirit & Opportunity', None, None, None),
#  ('The Muppet Christmas Carol', None, None, None),
#  ('Jumping Ship', None, None, None),
#  ('Fantasia 2000', None, None, None),
#  ('Zapped', None, None, None),
#  ('The Barefoot Executive', None, None, None),
#  ('The Fox and the Hound 2', None, None, None),
#  ('PJ Masks', None, None, None),
#  ('Get a Clue', None, None, None),
#  ('Winged Seduction: Birds of Paradise', None, None, None),
#  ('Marvel Studios: Assembling a Universe', None, None, None),
#  ('Dinosaur', None, None, None),
#  ('Girl vs. Monster', None, None, None),
#  ('Unlikely Animal Friends', None, None, None),
#  ('Spider-Man', None, None, None),
#  ('Splash', None, None, None),
#  ('The Little Mermaid II: Return to the Sea', None, None, None),
#  ('The Princess Diaries 2: Royal Engagement', None, None, None),
#  ('Pocahontas II: Journey to a New World', None, None, None),
#  ('Red Tails', None, None, None),
#  ('The Olympic Elk', None, None, None),
#  ('Gravity Falls', None, None, None),
#  ('Tangled', None, None, None),
#  ('Vampirina', None, None, None),
#  ('Easter Island Unsolved', None, None, None),
#  ('United States of Animals', None, None, None),
#  ('Kingdom of the White Wolf', None, None, None),
#  ('Stepsister From Planet Weird', None, None, None),
#  ('A Tale of Two Critters', None, None, None),
#  ('12 Dates of Christmas', None, None, None),
#  ('Meet the Deedles', None, None, None),
#  ('Iron Man 2', None, None, None),
#  ('Star Wars: Episode VIII – The Last Jedi', None, None, None),
#  ('Jack', None, None, None),
#  ('Fish Hooks', None, None, None),
#  ('The Bears and I', None, None, None),
#  ('Secretariat', None, None, None),
#  ('A Goofy Movie', None, None, None),
#  ('Honey, I Blew Up the Kid', None, None, None),
#  ('Herbie Goes Bananas', None, None, None),
#  ('Captain America: Civil War', None, None, None),
#  ('Sharks of Lost Island', None, None, None),
#  ('Rookie of the Year', None, None, None),
#  ('Primal Survivor', None, None, None),
#  ('Quack Pack', None, None, None),
#  ('Great Migrations', None, None, None),
#  ('Best Friends Whenever', None, None, None),
#  ('Twitches', None, None, None),
#  ('That Darn Cat', None, None, None),
#  ('Bride of Boogedy', None, None, None),
#  ('The Little Mermaid', None, None, None),
#  ('Lego Star Wars: The Yoda Chronicles', None, None, None),
#  ('Rocky Mountain Animal Rescue', None, None, None),
#  ('Marvel 75 Years: From Pulp to Pop!', None, None, None),
#  ('Operation Dumbo Drop', None, None, None),
#  ('The Swap', None, None, None),
#  ('Spider-Woman', None, None, None),
#  ('Ice Age: The Great Egg-Scapade', None, None, None),
#  ('Bedknobs and Broomsticks', None, None, None),
#  ('Amy', None, None, None),
#  ('Tall Tale', None, None, None),
#  ('High School Musical: The Musical: The Series', None, None, None),
#  ('Return to Never Land', None, None, None),
#  ('Freaky Friday', None, None, None),
#  ('One Magic Christmas', None, None, None),
#  ('Man Among Cheetahs', None, None, None),
#  ('First Kid', None, None, None),
#  ('The Cheetah Girls: One World', None, None, None),
#  ('Giants of the Deep Blue', None, None, None),
#  ('Marvel Rising: Operation Shuri', None, None, None),
#  ('The Even Stevens Movie', None, None, None),
#  ('Miracle at Midnight', None, None, None),
#  ('The Muppets', None, None, None),
#  ('Saludos Amigos', None, None, None),
#  ('High School Musical 2', None, None, None),
#  ('Bonkers', None, None, None),
#  ('Freaky Friday', None, None, None),
#  ('Kingdom of the Apes: Battle Lines', None, None, None),
#  ('Guardians of the Galaxy', None, None, None),
#  ('Meet the Robinsons', None, None, None),
#  ('Captain America: The First Avenger', None, None, None),
#  ('Super Buddies', None, None, None),
#  ('102 Dalmatians', None, None, None),
#  ('Violetta', None, None, None),
#  ('The Absent-Minded Professor', None, None, None),
#  ('Mars Needs Moms', None, None, None),
#  ('Newsies: The Broadway Musical', None, None, None),
#  ('Princess Protection Program', None, None, None),
#  ('Johnny Kapahala: Back on Board', None, None, None),
#  ('The Adventures of Huck Finn', None, None, None),
#  ('The Simpsons', None, None, None),
#  ('Atlantis: Milo’s Return', None, None, None),
#  ('Disney Gallery: The Mandalorian', None, None, None),
#  ('The Prince and the Pauper', None, None, None),
#  ('Bolt', None, None, None),
#  ('Darkwing Duck', None, None, None),
#  ('The Black Cauldron', None, None, None),
#  ('Recess: All Growed Down', None, None, None),
#  ('Teacher’s Pet', None, None, None),
#  ('Star Wars: The Clone Wars Season 7', None, None, None),
#  ('Diary of a Future President', None, None, None),
#  ('Before the Flood', None, None, None),
#  ('Hostile Planet', None, None, None),
#  ('The Many Adventures of Winnie the Pooh', None, None, None),
#  ('Mighty Joe Young', None, None, None),
#  ('Kronk’s New Groove', None, None, None),
#  ('Just Roll with It', None, None, None),
#  ('Prowlers of the Everglades', None, None, None),
#  ('Lego Star Wars: The Freemaker Adventures', None, None, None),
#  ('Return from Witch Mountain', None, None, None),
#  ('Benji the Hunted', None, None, None),
#  ('The Apple Dumpling Gang', None, None, None),
#  ('Pollyanna', None, None, None),
#  ('Casebusters', None, None, None),
#  ('George of the Jungle 2', None, None, None),
#  ('Heavyweights', None, None, None),
#  ('Hannah Montana and Miley Cyrus: Best of Both Worlds Concert', None, None, None),
#  ('Decorating Disney: Holiday Magic', None, None, None),
#  ('Sharpay’s Fabulous Adventure', None, None, None),
#  ('Lego Star Wars: Droid Tales', None, None, None),
#  ('Out There with Jack Randall', None, None, None),
#  ('Rip Girls', None, None, None),
#  ('Teen Beach Movie 2', None, None, None),
#  ('Double Teamed', None, None, None),
#  ('The Rescuers', None, None, None),
#  ('Cinderella II: Dreams Come True', None, None, None),
#  ('Into the Okavango', None, None, None),
#  ('Peter Pan', None, None, None),
#  ('Legend of the Three Caballeros', None, None, None),
#  ('Doctor Strange', None, None, None),
#  ('The Great Muppet Caper', None, None, None),
#  ('High School Musical 3: Senior Year', None, None, None),
#  ('Thor', None, None, None),
#  ('Jane', None, None, None),
#  ('Ice Princess', None, None, None),
#  ('Herbie Goes to Monte Carlo', None, None, None),
#  ('The Parent Trap', None, None, None),
#  ('The Thirteenth Year', None, None, None),
#  ('Tuck Everlasting', None, None, None),
#  ('Adventures in Babysitting', None, None, None),
#  ('Snowglobe', None, None, None),
#  ('Avengers Assemble', None, None, None),
#  ('The Rookie', None, None, None),
#  ('Mickey, Donald, Goofy: The Three Musketeers', None, None, None),
#  ('Apollo: Missions to the Moon', None, None, None),
#  ('The Three Caballeros', None, None, None),
#  ('Timmy Failure: Mistakes Were Made', None, None, None),
#  ('Expedition Amelia', None, None, None),
#  ('Inhumans', None, None, None),
#  ('Planet of the Birds', None, None, None),
#  ('The Wizards Return: Alex vs. Alex', None, None, None),
#  ('Puppy Dog Pals', None, None, None),
#  ('Pete’s Dragon', None, None, None),
#  ('America’s Heart and Soul', None, None, None),
#  ('Three Men and a Little Lady', None, None, None),
#  ('The Straight Story', None, None, None),
#  ('Big City Greens', None, None, None),
#  ('Bears', None, None, None),
#  ('Water Birds', None, None, None),
#  ('Dumbo', None, None, None),
#  ('101 Dalmatians II: Patch’s London Adventure', None, None, None),
#  ('Halloweentown High', None, None, None),
#  ('Rogue One: A Star Wars Story', None, None, None),
#  ('The Sign of Zorro', None, None, None),
#  ('Sultan and the Rock Star', None, None, None),
#  ('Camp Rock 2: The Final Jam', None, None, None),
#  ('Cars 3', None, None, None),
#  ('The Lizzie McGuire Movie', None, None, None),
#  ('The Living Desert', None, None, None),
#  ('African Cats', None, None, None),
#  ('The Journey of Natty Gann', None, None, None),
#  ('Ant-Man', None, None, None),
#  ('Mulan', None, None, None),
#  ('Mary Poppins', None, None, None),
#  ('Life With Mikey', None, None, None),
#  ('High School Musical', None, None, None),
#  ('Phantom of the Megaplex', None, None, None),
#  ('In Beaver Valley', None, None, None),
#  ('101 Dalmatians', None, None, None),
#  ('The Sandlot 2', None, None, None),
#  ('The Jungle Book: Mowgli’s Story', None, None, None),
#  ('Cars', None, None, None),
#  ('Guardians of the Galaxy Vol. 2', None, None, None),
#  ('Star vs. the Forces of Evil', None, None, None),
#  ('The Replacements', None, None, None),
#  ('Sammy, the Way-Out Seal', None, None, None),
#  ('Wicked Tuna: Outer Banks', None, None, None),
#  ('The Sword in the Stone', None, None, None),
#  ('The Brave Little Toaster to the Rescue', None, None, None),
#  ('The Evermoor Chronicles', None, None, None),
#  ('Captain Marvel', None, None, None),
#  ('Fairy Tale Weddings', None, None, None),
#  ('Mission to the Sun', None, None, None),
#  ('Horse Sense', None, None, None),
#  ('Ruby Bridges', None, None, None),
#  ('Titanic: 20 Years Later With James Cameron', None, None, None),
#  ('Phineas and Ferb the Movie: Across the 2nd Dimension', None, None, None),
#  ('Secrets of the Zoo: Tampa', None, None, None),
#  ('Pete’s Dragon', None, None, None),
#  ('The Poof Point', None, None, None),
#  ('Leroy & Stitch', None, None, None),
#  ('Awesome Animals', None, None, None),
#  ('Twitches Too', None, None, None),
#  ('Prairie Dog Manor', None, None, None),
#  ('Stuck in the Middle', None, None, None),
#  ('Elena of Avalor', None, None, None),
#  ('Encore!', None, None, None),
#  ('Marvel Rising: Playing with Fire', None, None, None),
#  ('Jungle Cat', None, None, None),
#  ('Whispers: An Elephant’s Tale', None, None, None),
#  ('The Pacifier', None, None, None),
#  ('The Jungle Book 2', None, None, None),
#  ('Spider-Man Unlimited', None, None, None),
#  ('Journey to the Center of the Earth', None, None, None),
#  ('Dr. Doolittle 2', None, None, None),
#  ('Let It Shine', None, None, None),
#  ('Jonas Brothers: The 3D Concert Experience', None, None, None),
#  ('Sydney to the Max', None, None, None),
#  ('The Boy Who Talked to Badgers', None, None, None),
#  ('Andi Mack', None, None, None),
#  ('Teen Beach Movie', None, None, None),
#  ('Zenon: Girl of the 21st Century', None, None, None),
#  ('Moana', None, None, None),
#  ('Tom and Huck', None, None, None),
#  ('Gus', None, None, None),
#  ('Milo Murphy’s Law', None, None, None),
#  ('Thumbelina', None, None, None),
#  ('Disney Insider', None, None, None),
#  ('Out of the Box', None, None, None),
#  ('The Three Musketeers', None, None, None),
#  ('Star Wars: Episode III – Revenge of the Sith', None, None, None),
#  ('The Lion King 1½', None, None, None),
#  ('Eight Below', None, None, None),
#  ('You Wish!', None, None, None),
#  ('The Haunted Mansion', None, None, None),
#  ('Jake and the Never Land Pirates', None, None, None),
#  ('Wild Yellowstone', None, None, None),
#  ('The Sandlot', None, None, None),
#  ('The Flood', None, None, None),
#  ('Tangled: The Series', None, None, None),
#  ('Lab Rats: Elite Force', None, None, None),
#  ('Guardians of the Galaxy', None, None, None),
#  ('Secrets of Life', None, None, None),
#  ('Henry Hugglemonster', None, None, None),
#  ('I Didn’t Do It', None, None, None),
#  ('The Million Dollar Duck', None, None, None),
#  ('The Lion King II: Simba’s Pride', None, None, None),
#  ('Alice in Wonderland', None, None, None),
#  ('Secret of the Wings', None, None, None),
#  ('Raven’s Home', None, None, None),
#  ('Going to the Mat', None, None, None),
#  ('Brink!', None, None, None),
#  ('The Muppets', None, None, None),
#  ('Bambi II', None, None, None),
#  ('Dog: Impossible', None, None, None),
#  ('Miracle in Lane 2', None, None, None),
#  ('The Hunchback of Notre Dame II', None, None, None),
#  ('Chicken Little', None, None, None),
#  ('The Rocketeer', None, None, None),
#  ('Bug Juice: My Adventures at Camp', None, None, None),
#  ('A Ring of Endless Light', None, None, None),
#  ('Stonehenge Decoded: Secrets Revealed', None, None, None),
#  ('Paradise Islands', None, None, None),
#  ('Star Wars Episode IX: The Rise of Skywalker', None, None, None),
#  ('The Return of Jafar', None, None, None),
#  ('Perri', None, None, None),
#  ('Old Dogs', None, None, None),
#  ('While You Were Sleeping', None, None, None),
#  ('Avengers: Age of Ultron', None, None, None),
#  ('Swiss Family Robinson', None, None, None),
#  ('Aliens of the Deep', None, None, None),
#  ('Roving Mars', None, None, None),
#  ('My Friends Tigger & Pooh', None, None, None),
#  ('Science Fair', None, None, None),
#  ('The Ultimate Christmas Present', None, None, None),
#  ('Lady and the Tramp', None, None, None),
#  ('Prom', None, None, None),
#  ('Glory Road', None, None, None),
#  ('A Very Merry Pooh Year', None, None, None),
#  ('Return to Oz', None, None, None),
#  ('Doug’s 1st Movie', None, None, None),
#  ('Recess', None, None, None),
#  ('Mars and Beyond', None, None, None),
#  ('Fantasia', None, None, None),
#  ('Mr. Boogedy', None, None, None),
#  ('Fuzzbucket', None, None, None),
#  ('X-Men: Evolution', None, None, None),
#  ('Recess: Taking the Fifth Grade', None, None, None),
#  ('Honey, I Shrunk the Kids', None, None, None),
#  ('Descendants', None, None, None),
#  ('Waking Sleeping Beauty', None, None, None),
#  ('America’s Funniest Home Videos', None, None, None),
#  ('The Shaggy Dog', None, None, None),
#  ('Trail of the Panda', None, None, None),
#  ('Freaky Friday', None, None, None),
#  ('Geek Charming', None, None, None),
#  ('Cool Runnings', None, None, None),
#  ('Swiss Family Robinson', None, None, None),
#  ('The Avengers: United They Stand', None, None, None),
#  ('Confessions of a Teenage Drama Queen', None, None, None),
#  ('Sister Act 2: Back in the Habit', None, None, None),
#  ('Avatar', None, None, None),
#  ('Treasure Planet', None, None, None),
#  ('Be Our Chef', None, None, None),
#  ('It’s A Dog’s Life With Bill Farmer', None, None, None),
#  ('Austin and Ally', None, None, None),
#  ('Robin Hood', None, None, None),
#  ('Ice Age', None, None, None),
#  ('Cloud 9', None, None, None),
#  ('The Avengers: Earth’s Mightiest Heroes', None, None, None),
#  ('Star Wars: Episode I – The Phantom Menace', None, None, None),
#  ('Good Luck Charlie', None, None, None),
#  ('Fantastic Four', None, None, None),
#  ('Wreck-It Ralph', None, None, None),
#  ('Gotta Kick It Up!', None, None, None),
#  ('Read It and Weep', None, None, None),
#  ('Go Figure', None, None, None),
#  ('Unidentified Flying Oddball', None, None, None),
#  ('The Good Dinosaur', None, None, None),
#  ('Tarzan & Jane', None, None, None),
#  ('The Incredible Journey', None, None, None),
#  ('The Adventures of Ichabod and Mr. Toad', None, None, None),
#  ('20,000 Leagues Under the Sea', None, None, None),
#  ('The Greatest Game Ever Played', None, None, None),
#  ('Dan in Real Life', None, None, None),
#  ('Those Calloways', None, None, None),
#  ('White Fang', None, None, None),
#  ('Remember the Titans', None, None, None),
#  ('X-Men', None, None, None),
#  ('Fantastic Four: World’s Greatest Heroes', None, None, None),
#  ('Into the Grand Canyon', None, None, None),
#  ('Drain The Great Lakes', None, None, None),
#  ('Sacred Planet', None, None, None),
#  ('Stuck in the Suburbs', None, None, None),
#  ('The Nightmare Before Christmas', None, None, None),
#  ('Lab Rats', None, None, None),
#  ('National Treasure: Book of Secrets', None, None, None),
#  ('James and the Giant Peach', None, None, None),
#  ('Kim Possible Movie: So the Drama', None, None, None),
#  ('Winnie the Pooh', None, None, None),
#  ('The Odd Life of Timothy Green', None, None, None),
#  ('The Ghosts of Buxley Hall', None, None, None),
#  ('Treasure of Matecumbe', None, None, None),
#  ('The Cheetah Girls 2', None, None, None),
#  ('Spider-Man', None, None, None),
#  ('Lizzie McGuire', None, None, None),
#  ('Secrets of Christ’s Tomb: Explorer Special', None, None, None)]

# %% [markdown]
# Based on the results of this query, Disney+ should look into what made the success of Coco, Avengers: Endgame, The Kid, and Inside Out. These 4 movies are found on both the IMDb and RottenTomatoes top lists, so clearly they did something right. By looking into the stories of how these films were made and what made them popular, maybe Disney could find similar success in new projects. There are also films found in either the IMDb or RottenTomatoes lists that are only on one that could also be looked into.

# %% [markdown]
# ### Related Question Queries #2

# %% [markdown]
# Which genres should Disney focus on making new movies in to bolester sales?
#
# Since we established that 'R' rated movies are the most popular, perhaps Disney could try to put their own spin on the genres most usually related to the 'R' rating and tone it down so it still fits within their brand.
#
# This query will allow Disney+ to see which genre of movie is most popular/is viewed as the best films. By trying their hand at making films that are in line with the most popular genres, the site can hopefully pull in more customers who may be intrguied with the new content.
#
# SQL Features Used:
#     GROUP BY,
#     CTE,
#     Subquery,
#     Window Function (RANK)

# %%
# %%sql
# WITH genre_totals AS (
#     SELECT
#         COUNT(*) AS total_movies,
#         genre
#     FROM
#     (
#         SELECT
#             'rotten_tomatoes' AS source,
#             genre
#         FROM rotten_tomatoes rt
#         UNION ALL
#         SELECT
#             'imdb' AS source,
#             genre
#         FROM imdb i
#     ) joined_imdb_rotten_tomatoes
#     GROUP BY genre
#     ORDER BY COUNT(*) DESC
# )
# SELECT
#     RANK() OVER (ORDER BY total_movies DESC) AS genre_rank,
#     genre,
#     total_movies
# FROM genre_totals;
# Out:
#  * mysql://admin:***@lmu-dev-01.czdondpz1m2v.us-east-2.rds.amazonaws.com/sql_project
# 16 rows affected.
# [(1, 'Drama', 101),
#  (2, 'Action', 30),
#  (3, 'War', 27),
#  (4, 'Crime', 25),
#  (5, 'Comedy', 22),
#  (6, 'Romance', 20),
#  (6, 'Family', 20),
#  (6, 'Sci-fi', 20),
#  (9, 'Musical', 15),
#  (9, 'Thriller', 15),
#  (11, 'Horror', 11),
#  (12, 'Mystery', 10),
#  (13, 'Noir', 9),
#  (13, 'Fantasy', 9),
#  (15, 'Adventure', 8),
#  (15, 'Western', 8)]

# %% [markdown]
# Based on the results of this query, Disney+ should add drama, action, war, and crime movies to their catalog, as they are the highest ranked genres. These are genres that we found to be closely associated with 'R' ratings, so either Disney can branch out to more adult movies as previously stated, or they can try to take a crack at making movies that fit within these genres while still being a 'PG-13' rating or lower to maintain their image.
